# %% [markdown]
# # Comprobación de correcta ingesta

# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine(
    "postgresql://postgres:postgres@localhost:5432/airbnb"
)

listings_db = pd.read_sql(
    "SELECT * FROM raw_listings LIMIT 5",
    engine
)

reviews_db = pd.read_sql(
    "SELECT * FROM raw_reviews LIMIT 5",
    engine
)

listings_db.head(), reviews_db.head()
# Out:
# (       id                          listing_url       scrape_id last_scraped  \
#  0   48154   https://www.airbnb.com/rooms/48154  20250923203019   2025-09-24
#  1  137143  https://www.airbnb.com/rooms/137143  20250923203019   2025-09-24
#  2  149715  https://www.airbnb.com/rooms/149715  20250923203019   2025-09-24
#  3  165971  https://www.airbnb.com/rooms/165971  20250923203019   2025-09-24
#  4  276455  https://www.airbnb.com/rooms/276455  20250923203019   2025-09-24
#
#              source                                       name  \
#  0      city scrape              Precioso apartamento con wifi
#  1      city scrape             PENTHOUSE  ON FRONT LINE BEACH
#  2      city scrape  1900 Style Valencian Beach  Home for 10px
#  3      city scrape                   ★ Architectural touch! ★
#  4  previous scrape        Great Room in an apartment,Valencia
#
#                                           description  \
#  0  Second floor on a farm from the late 19th cent...
# ...

# %% [markdown]
# Hemos añadido conservado, además de barrio, 'district'. Esta columna puede sernos útil para cruzarla con los datos geográficos de libre acceso del ayuntamiento de València, ya que están agrupados por distritos en vez de barrios.

# %%
engine = create_engine("postgresql://postgres:postgres@localhost:5432/airbnb")

df = pd.read_sql("select * from public.stg_listings limit 5", engine)
df
# Out:
#    listing_id  host_id        neighbourhood          district  latitude  \
# 0       48154   219476             MORVEDRE         LA SAIDIA  39.48375
# 1      137143   670775             EL SALER   POBLATS DEL SUD  39.36335
# 2      149715     5947  CABANYAL-CANYAMELAR  POBLATS MARITIMS  39.46746
# 3      165971   791187           LA ROQUETA         EXTRAMURS  39.46790
# 4      276455  1444357          LA CARRASCA           ALGIROS  39.47317
#
#    longitude                property_type        room_type  accommodates  \
# 0   -0.37502           Entire rental unit  Entire home/apt             4
# 1   -0.31932           Entire rental unit  Entire home/apt             7
# 2   -0.32813                  Entire home  Entire home/apt            10
# 3   -0.38206           Entire rental unit  Entire home/apt             4
# 4   -0.33932  Private room in rental unit     Private room             1
#
#    bedrooms  beds  bathrooms  price  minimum_nights  availability_365  \
# ...

# %%
# Revisar stg_listings
df_listings = pd.read_sql("SELECT * FROM public.stg_listings LIMIT 5", engine)
df_listings

# Revisar stg_reviews
df_reviews = pd.read_sql("SELECT * FROM public.stg_reviews LIMIT 5", engine)
df_reviews
# Out:
#    review_id  listing_id  reviewer_id    reviewer_name review_date  \
# 0     117554       48154       180238           Martha  2010-10-12
# 1     145645       48154       204240             Mark  2010-11-28
# 2     190572       48154       258565         Domenico  2011-03-01
# 3     195081       48154       213496  Romina & Martín  2011-03-08
# 4     218435       48154       340330            Jenna  2011-04-05
#
#                                             comments
# 0  Toni's place was perfect in so many ways.  It ...
# 1  Awesome stay!! We'd recommend Toni's apartment...
# 2  really nice house in a wonderfull position! yo...
# 3  Apartamento muy agradable, al igual que su pro...
# 4  Was a great apartment, easy access to the site...
